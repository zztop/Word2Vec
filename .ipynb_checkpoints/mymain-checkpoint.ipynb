# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from lightgbm import LGBMClassifier
import xgboost as xgb
import seaborn as sns
from sklearn.metrics import roc_auc_score
# train = pd.read_csv('data.tsv', sep=' ', quotechar='"', escapechar='\\')

# %%
all_data = pd.read_csv('data.tsv', sep=' ', quotechar='"', escapechar='\\')
# 1,2,3
s=3

splits =  pd.read_csv("splits.csv",low_memory=True, sep='\t')

# %%
test = all_data[all_data.index.isin(splits[f'split_{s}'])]
train = all_data[~all_data.index.isin(splits[f'split_{s}'])]

# %%
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords ,wordnet
from nltk.stem import  WordNetLemmatizer ,PorterStemmer
from collections import Counter 

lemmatiser = WordNetLemmatizer()
ps = PorterStemmer()
def get_pos( word ):
    w_synsets = wordnet.synsets(word)

    pos_counts = Counter()
    pos_counts["n"] = len(  [ item for item in w_synsets if item.pos()=="n"]  )
    pos_counts["v"] = len(  [ item for item in w_synsets if item.pos()=="v"]  )
    pos_counts["a"] = len(  [ item for item in w_synsets if item.pos()=="a"]  )
    pos_counts["r"] = len(  [ item for item in w_synsets if item.pos()=="r"]  )
    
    most_common_pos_list = pos_counts.most_common(3)
    return most_common_pos_list[0][0]

def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    meaningful_words = [lemmatiser.lemmatize( w,get_pos(w)) for w in meaningful_words]
    
    
#     #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
num_reviews = train["review"].size
# Initialize an empty list to hold the clean reviews
clean_train_reviews = []

# Loop over each review; create an index i that goes from 0 to the length
# of the movie review list 
for i in range( 0, num_reviews ):
    # Call our function for each one, and add the result to the list of
    # clean reviews
    clean_train_reviews.append( review_to_words( train["review"].iloc[i] ) )

# %%
num_reviews = len(test["review"])
clean_test_reviews = [] 

print ("Cleaning and parsing the test set movie reviews...\n")
for i in range(0,num_reviews):
#     if( (i+1) % 1000 == 0 ):
#         print ("Review %d of %d\n" % (i+1, num_reviews))
    clean_review = review_to_words( test["review"].iloc[i] )
    clean_test_reviews.append( clean_review )
# Out:
# Cleaning and parsing the test set movie reviews...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfv = TfidfVectorizer(max_df=0.55,max_features=3000,
        strip_accents='unicode', analyzer='word',token_pattern=r'(?u)\b\w{3,}\b',
        ngram_range=(1, 2), use_idf=True,smooth_idf=1,sublinear_tf=True,
        stop_words = 'english',norm='l2')



tfv.fit(list(clean_train_reviews) + list(clean_test_reviews))
train_data_features = tfv.transform(clean_train_reviews)
test_data_features = tfv.transform(clean_test_reviews)

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB()
clf.fit(train_data_features, train["sentiment"] )

roc_auc_score(test.sentiment, clf.predict_proba(test_data_features)[:,1])
# Out:
# 0.9257332105173137

# %%
# %%time
from sklearn.linear_model import LogisticRegressionCV



model = LogisticRegressionCV(tol=0.0001, fit_intercept=True, intercept_scaling=1.0, 
                         cv=2,scoring='roc_auc',n_jobs=2,max_iter=4000,Cs=10,penalty='l2')

model.fit(train_data_features, train["sentiment"])
y_pred=model.predict_proba(test_data_features)[:,1]
output = model.predict(test_data_features)
print(roc_auc_score(test.sentiment, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'roc_auc_score' is not defined

# %%
clf = LGBMClassifier()
params = {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 0.1, 'importance_type': 'split', 'learning_rate': 0.01, 'max_depth': 10, 'min_child_samples': 20, 'min_child_weight': 1, 'min_split_gain': 0.04, 'n_estimators': 10000, 'n_jobs': -1, 'num_leaves': 20, 'objective': None, 'random_state': None, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'silent': True, 'subsample': 1.0, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': 4}
clf.set_params(**params)
# clf.fit(train_data_features, train["sentiment"],eval_metric= 'auc', verbose= 1000)


# roc_auc_score(test.sentiment, clf.predict_proba(test_data_features)[:,1])
# Out:
# 0.9468997477286444

# %%
import gc
from skopt.space import Real, Integer
from skopt import gp_minimize

# {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 0.5684297315960845, 'importance_type': 'split', 'learning_rate': 0.3426509697582906, 'max_depth': 6, 'min_child_samples': 20, 'min_child_weight': 48, 'min_split_gain': 0.3631100008156993, 'n_estimators': 10000, 'n_jobs': -1, 'num_leaves': 37, 'objective': None, 'random_state': None, 'reg_alpha': 0.5820197920751072, 'reg_lambda': 0.5373732294490108, 'silent': True, 'subsample': 0.82081967678168, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': 4}

# space_lgbm  = [Integer(5, 10, name='max_depth'),
#           Integer(30, 40, name='num_leaves'),
#           Integer(1, 10, name='min_child_weight'),
#           Real(0.8, 1, name='subsample'),
#           Real(0.8, 1, name='colsample_bytree'),
#           Real(0.15,0.3,name='learning_rate'),
#           Real(0.2,0.5,name='min_split_gain'),
#           Real(0.01,0.3, name='reg_alpha'),
#           Real(0.5,1,name='reg_lambda')
#          ]
space_lgbm  = [Integer(3, 10, name='max_depth'),
          Integer(20, 30, name='num_leaves'),
          Integer(1, 2, name='min_child_weight'),
          Real(0.9, 1, name='subsample'),
          Real(0.1, 1, name='colsample_bytree'),
          Real(0.01,0.03,name='learning_rate'),
          Real(0.01,0.04,name='min_split_gain'),
          Real(0,0.01, name='reg_alpha'),
          Real(0.9,1,name='reg_lambda')
         ]

def objective_lgbm(values):
    params = {'nthread':4,
            'n_estimators':10000,
            'learning_rate':0.01,
            'num_leaves':values[1],
            'colsample_bytree':values[4],
            'subsample':values[3],
            'max_depth':10,
            'reg_alpha':values[7],
            'reg_lambda':values[8],
            'min_split_gain':values[6],
            'min_child_weight':values[2]}
    clf = LGBMClassifier()
    clf.set_params(**params)
    clf.fit(train_data_features, train["sentiment"],eval_metric= 'auc', verbose= 1000)
    
    print(clf.get_params())
    loss=roc_auc_score(test.sentiment, clf.predict_proba(test_data_features)[:,1])
    print(f'log loss {loss}')
    gc.collect()
    return -loss
def get_lgbm_param():
    res_gp = gp_minimize(objective_lgbm, space_lgbm, n_calls=30,
                         random_state=0,n_random_starts=10)
    print("Best score=%.4f" % res_gp.fun)  
# get_lgbm_param()

# %%
import gc
from skopt.space import Real, Integer
from skopt import gp_minimize
    
    
space  = [Integer(3, 10, name='max_depth'),
          Integer(5, 10, name='num_leaves'),
          Integer(1, 100, name='min_child_weight'),
          Real(1, 100,  name='scale_pos_weight'),
          Real(0, 1, name='subsample'),
          Real(0, 1, name='colsample_bytree'),
          Real(0.01,0.2,name='learning_rate'),
          Real(0.8,1, name='reg_alpha'),
          Real(0.8,1,name='reg_lambda')          
         ]
def objective(values):
    params = {'max_depth': values[0], 
          'num_leaves': values[1], 
          'min_child_weight': 1, 
          'scale_pos_weight': 1,
            'subsample': values[4],
            'colsample_bytree': values[5],
             'metric':'auc',
             'nthread': 4,
             'boosting_type': 'gbdt',
             'objective': 'binary:logistic',
              'reg_alpha':values[7],
              'reg_lambda':values[8],
             'learning_rate':values[6]}
    xgb_model = xgb.XGBClassifier()
    xgb_model.set_params(**params)
    
    xgb_model.fit(train_data_features, train["sentiment"],eval_metric= 'auc', verbose= 1000)
    
    print(xgb_model.get_params())
    loss=roc_auc_score(test.sentiment, xgb_model.predict_proba(test_data_features)[:,1])
    print(f'log loss {loss}')
    gc.collect()
    return -loss
def get_xboost_param():
    res_gp = gp_minimize(objective, space, n_calls=30,
                         random_state=0,n_random_starts=10)
    print("Best score=%.4f" % res_gp.fun)  
# get_xboost_param()

# %%
from sklearn.ensemble import RandomForestClassifier
import gc
from skopt.space import Real, Integer
from skopt import gp_minimize

    
    
space  = [Integer(3,10, name='max_depth'),
          Integer(5, 10, name='min_samples_leaf'),
          Real(0.1, 0.9, name='min_samples_split'),
          Integer(2, 100,  name='max_leaf_nodes'),
          Real(0, 10, name='min_impurity_decrease'),         
         ]
def objective(values):
    params = {'max_depth': values[0], 
          'min_samples_leaf': values[1], 
          'min_samples_split': values[2], 
          'max_leaf_nodes': values[3],
            'min_impurity_decrease': values[4]}
    rf = RandomForestClassifier()
    rf.set_params(**params)
    
    rf.fit(train_data_features, train["sentiment"])
    
    print(rf.get_params())
    loss=roc_auc_score(test.sentiment, rf.predict_proba(test_data_features)[:,1])
    print(f'log loss {loss}')
    gc.collect()
    return -loss
def get_rf_param():
    res_gp = gp_minimize(objective, space, n_calls=30,
                         random_state=0,n_random_starts=10)
    print("Best score=%.4f" % res_gp.fun)  
# get_rf_param()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import pipeline,preprocessing



# We will use logistic regression here..
lr_model = LogisticRegression(max_iter=4000)

# Create the pipeline 
clf = pipeline.Pipeline([('lr', lr_model)])

# parameter grid
param_grid = {'lr__penalty': ['l2','l1'],'lr__C':[ 1.1,1,1.25,1.2],'lr__tol':[0.00001]}

model = GridSearchCV(estimator=clf, param_grid=param_grid, scoring='roc_auc',
                                 verbose=10, n_jobs=2, refit=True, cv=2)

# Fit Grid Search Model
# model.fit(train_data_features, train["sentiment"])  # we can use the full data here but im only using xtrain. 

# loss=roc_auc_score(test.sentiment, model.predict_proba(test_data_features)[:,1])
# print(f'loss is {loss}')
# print("Best score: %0.3f" % model.best_score_)
# print("Best parameters set:")
# best_parameters = model.best_estimator_.get_params()
# for param_name in sorted(param_grid.keys()):
#     print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Batch computation too fast (0.1352s.) Setting batch_size=2.
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done  16 out of  16 | elapsed:    1.3s finished
# /home/zztop/.local/share/virtualenvs/word2vec-EFHczPd3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# loss is 0.9514975718821702
# Best score: 0.944
# Best parameters set:
# 	lr__C: 1.25
# 	lr__penalty: 'l2'
# 	lr__tol: 1e-05

# %%
from sklearn.linear_model import SGDClassifier
import gc
from skopt.space import Real, Integer,Categorical
from skopt import gp_minimize
from sklearn.metrics import roc_auc_score

    
    
space  = [Integer(3,10, name='max_depth'),
#           Categorical('l2', 'elasticnet', name='penalty'),
          Real(0.0001, 0.2, name='learning_rate'),
          Real(0.09, 0.11,  name='l1_ratio'),
          Real(0.00000001,0.1, name='alpha'),         
         ]
def objective(values):
    params = {
        'penalty':'l2',
#           'learning_rate': values[1],
          'l1_ratio': values[2],
            'alpha': values[3]
    }
    rf = SGDClassifier(loss='log',tol=0.00001)
    rf.set_params(**params)
    
    rf.fit(train_data_features, train["sentiment"])
    
    print(rf.get_params())
    loss=roc_auc_score(test.sentiment, rf.predict_proba(test_data_features)[:,1])
    print(f'log loss {loss}')
    gc.collect()
    return -loss
def get_gd_param():
    res_gp = gp_minimize(objective, space, n_calls=30,
                         random_state=0,n_random_starts=10)
    print("Best score=%.4f" % res_gp.fun)  
# get_gd_param()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import RidgeClassifier
from sklearn import pipeline,preprocessing
import numpy as np



# We will use logistic regression here..
lr_model = SGDClassifier(loss='log',tol=0.00001)

# Create the pipeline 
clf = pipeline.Pipeline([('lr', lr_model)])

# parameter grid
param_grid = {'lr__l1_ratio': [0.11],'lr__penalty':['elasticnet'],'lr__alpha':[.0002,0.0001,.00001]}

model = GridSearchCV(estimator=clf, param_grid=param_grid, scoring='roc_auc',
                                 verbose=10, n_jobs=2, iid=True, refit=True, cv=2)

# Fit Grid Search Model
model.fit(train_data_features, train["sentiment"])  # we can use the full data here but im only using xtrain. 

# loss=roc_auc_score(test.sentiment, model.predict_proba(test_data_features)[:,1])


# print(f'loss is {loss}')
# print("Best score: %0.3f" % model.best_score_)
# print("Best parameters set:")
# best_parameters = model.best_estimator_.get_params()
# for param_name in sorted(param_grid.keys()):
#     print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=2)]: Done   4 out of   6 | elapsed:    1.2s remaining:    0.6s
# [Parallel(n_jobs=2)]: Done   6 out of   6 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done   6 out of   6 | elapsed:    2.2s finished
# loss is 0.9493296217488834
# Best score: 0.944
# Best parameters set:
# 	lr__alpha: 0.0001
# 	lr__l1_ratio: 0.11
# 	lr__penalty: 'elasticnet'

# %%
x=pd.DataFrame({'keys':list(tfv.vocabulary_.keys()),'values':list(tfv.vocabulary_.values())})
x.sort_values(['values'],ascending=[0]).to_csv('myVocab.csv',header=True,index=False)

# %%
train.review.str.len().hist(bins=100)

# %%
test.review.str.len().hist(bins=100)

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
# %matplotlib inline

# fpr, tpr, _ = roc_curve(test_data_features.toarray(), y_pred)
plt.plot(test_data_features.toarray(), y_pred)

plt.xlabel("True Postive Rate")
plt.ylabel("False Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# train_fet=tfv.inverse_transform(train_data_features)
# all_train_words=[]
# for arr in train_fet:
#     for w in arr:
#         all_train_words.append(w) 
        
test_train_words=tfv.inverse_transform(test_data_features+train_data_features)
all_words=[]
for arr in test_train_words:
    for w in arr:
        all_words.append(w) 
    


word_cloud = WordCloud(width = 1000, height = 500, stopwords = STOPWORDS, background_color = 'red').generate(" ".join( list(set(all_words))))

plt.figure(figsize = (15,8))
plt.imshow(word_cloud)
plt.axis('off')
plt.show()
word_cloud.to_file('train_cloud.png')

# %%
def check_keywords(keywords):
    result = pd.DataFrame(columns=['not_present', 'positive'])
    for word in keywords:
        df = train.loc[train.review.str.contains(word, case=False)]
        result.loc[word] = [train.shape[0] - df.shape[0], df.sentiment.sum()]
    result = result / train.shape[0]
    result['negative'] = 1- result['not_present'] - result['positive']
    result.plot(kind='bar', stacked=True)
    plt.legend(loc='best')
    return result

keywords = ['good', 'bad', 'great', 'disaster', 'fun', 'phenomenal']
check_keywords(keywords)

# %%
coefs = pd.DataFrame(columns=['word'])


for word, ind in vectorizer.vocabulary_.items():
    coefs.loc[ind, 'word'] = word
coefs.sort_index(inplace=True)

coefs['coefs'] = lreg.coef_[0,:]
most_relevant_words = coefs.iloc[np.argsort(coefs.coefs.abs())].tail(20)
most_relevant_words.sort_values('coefs', inplace=True)

def plot_impact(words, impacts):
    pos_ind = (impacts > 0)
    position = np.arange(len(words))
    plt.barh(bottom=position[pos_ind], width=impacts[pos_ind], color='green')
    plt.barh(bottom=position[~pos_ind], width=impacts[~pos_ind], color='red')
    plt.yticks(position + 0.4 ,words)
    plt.show()
    
plot_impact(most_relevant_words.word.values, most_relevant_words.coefs.values)

# %%
import seaborn as sns
def words_impacts(text):
    baseline_ = pipeline.predict_proba([text])[:,1]
    words_list = text.split()
    text_excl_words = list()
    for i, word in enumerate(words_list):
        new_words_list = text.split()
        new_words_list.pop(i)
        text_excl_words.append(' '.join(new_words_list)) 
    impacts = baseline_ - pipeline.predict_proba(text_excl_words)[:, 1]
    return words_list, impacts, baseline_

def reshape_pad(iterable, shape, pad_value=0):
    n_ = len(iterable)
    pad_length = shape[0] * shape[1] - n_
    data = list(iterable)
    data.extend([pad_value for _ in range(pad_length)])
    assert len(data) == shape[0] * shape[1]
    data = np.reshape(data, shape)
    return data

def plot_text_with_impacts(words_list, impacts, n_cols=10):
    assert len(words_list) == len(impacts)
    n_rows = (len(words_list) // n_cols) + 1
    words = reshape_pad(words_list, (n_rows, n_cols), pad_value='')
    impact_data = reshape_pad(impacts, (n_rows, n_cols))
    plt.figure(figsize=(20, n_rows//2))
    sns.heatmap(impact_data, annot=words, square=False, fmt='')
    sns.set(font_scale=1)
    
words_list, impacts, baseline = words_impacts(review_sample.iloc[0])
plot_text_with_impacts(words_list, impacts, n_cols=15)

# %%
fig, axes = plt.subplots(ncols=2)
fig.set_size_inches(12,5)
fig.suptitle("Sentiment counts for train and test data", fontsize=16)
sns.countplot(train['sentiment'], ax=axes[0])
sns.countplot(data=pd.DataFrame({'sentiment':(output)}), ax=axes[1],x="sentiment")

# %%
import matplotlib.gridspec as gridspec
x=pd.DataFrame({'keys':list(tfv.vocabulary_.keys()),'values':list(tfv.idf_)})
x=x.sort_values(['values'],ascending=[0])
x.tail(50)

fig =plt.figure(constrained_layout=True)
gs = gridspec.GridSpec(2, 1, figure=fig)


ax = fig.add_subplot(gs[0, :])

ax.barh(x.tail(5)['keys'],x.tail(5)['values'],height=0.8,color='orange')
ax.set_ylabel('Words')
ax.set_xlabel('Idf')
ax.set_title('Top 5 words with Lowest IDF')

ax = fig.add_subplot(gs[1, :])
ax.barh(x.head(5)['keys'],x.head(5)['values'],height=0.8)

ax.set_ylabel('Words')
ax.set_xlabel('Idf')
ax.set_title('Top 5 words with Highest IDF')
# for ax in fig.axes:
#     matplotlib.pyplot.sca(ax)
#     plt.xticks(rotation=90)
fig, axes = plt.subplots(ncols=2)
fig.set_size_inches(12,5)
fig.suptitle("Sentiment counts for train and test data", fontsize=16)
sns.countplot(train['sentiment'], ax=axes[0])
sns.countplot(data=pd.DataFrame({'sentiment':(output)}), ax=axes[1],x="sentiment")
# Out:
# Text(0.5, 1.0, 'Top 5 words with Highest IDF')

# %%
fig =plt.figure(constrained_layout=True)
gs = gridspec.GridSpec(2, 1, figure=fig)


ax = fig.add_subplot(gs[0, :])

fig.set_size_inches(12,5)


fig.suptitle("Sentiment counts for train and test data", fontsize=16)
sns.countplot(data=pd.DataFrame({'Words':(all_words)}), ax=ax,x="Words")

# %%
df =pd.DataFrame({'Words':(all_words)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5059430ff63c> in <module>
# ----> 1 df =pd.DataFrame({'Words':(all_words)})
#
# NameError: name 'all_words' is not defined

# %%
tfv.vocabulary_
# Out:
# {'quite': 2108,
#  'enjoy': 797,
#  'reason': 2160,
#  'insight': 1328,
#  'world': 2961,
#  'rarely': 2126,
#  'treat': 2769,
#  'tell': 2665,
#  'struggle': 2565,
#  'second': 2341,
#  'performance': 1936,
#  'actor': 34,
#  'think': 2698,
#  'honest': 1241,
#  'convince': 543,
#  'portrayal': 2003,
#  'people': 1925,
#  'hear': 1198,
#  'outside': 1880,
#  'native': 1782,
#  'entertain': 806,
#  'irish': 1358,
#  'cast': 374,
#  'earth': 756,
#  'slightly': 2445,
#  'open': 1862,
#  'eye': 876,
#  'enjoy movie': 799,
#  'man': 1599,
#  'land': 1449,
#  'meet': 1640,
#  'girl': 1093,
#  'life': 1493,
#  'sort': 2473,
#  'monkey': 1697,
#  'hook': 1247,
#  'teach': 2650,
#  'fly': 1006,
#  'leave': 1477,
#  'cringe': 584,
#  'induce': 1315,
#  'aside': 140,
#  'short': 2395,
#  'make': 1580,
#  'sense': 2354,
#  'plot': 1979,
#  'sure': 2610,
#  'long': 1529,
#  'shoot': 2393,
#  'work': 2958,
#  'despite': 666,
#  'good': 1105,
#  'use': 2833,
#  'slow': 2447,
#  'motion': 1708,
#  'series': 2362,
#  'video': 2854,
#  'believe': 227,
#  'short film': 2396,
#  'film make': 962,
#  'make sense': 1591,
#  'really': 2146,
#  'begin': 221,
#  'start': 2518,
#  'chance': 395,
#  'deserve': 661,
#  'home': 1240,
#  'watch': 2899,
#  'television': 2664,
#  'know': 1437,
#  'talent': 2637,
#  'sing': 2420,
#  'competition': 499,
#  'american': 89,
#  'year': 2983,
#  'miss': 1685,
#  'potential': 2013,
#  'feel': 923,
#  'bad': 180,
#  'singer': 2421,
#  'grow': 1156,
#  'wish': 2944,
#  'cancel': 357,
#  'complaint': 501,
#  'care': 365,
#  'judge': 1405,
#  'joy': 1404,
#  'shakespeare': 2377,
#  'single': 2422,
#  'right': 2246,
#  'wrong': 2980,
#  'thing': 2691,
#  'kind': 1429,
#  'action': 28,
#  'god': 1100,
#  'sake': 2288,
#  'play': 1973,
#  'instead': 1334,
#  'dead': 625,
#  'end': 784,
#  'act': 23,
#  'production': 2063,
#  'try': 2785,
#  'explain': 860,
#  'sexual': 2372,
#  'disgust': 706,
#  'total': 2745,
#  'mother': 1706,
#  'uncle': 2803,
#  'bed': 218,
#  'utter': 2838,
#  'mean': 1633,
#  'relationship': 2188,
#  'impossible': 1300,
#  'slight': 2444,
#  'hint': 1224,
#  'sex': 2370,
#  'throw': 2715,
#  'character': 399,
#  'lot': 1543,
#  'way': 2906,
#  'understand': 2807,
#  'manage': 1600,
#  'mark': 1607,
#  'great': 1137,
#  'completely': 503,
#  'let': 1487,
#  'rest': 2224,
#  'face': 878,
#  'prince': 2046,
#  'good actor': 1107,
#  'make great': 1586,
#  'great film': 1141,
#  'rest cast': 2225,
#  'big': 244,
#  'fan': 898,
#  'stephen': 2528,
#  'king': 1432,
#  'love': 1550,
#  'run': 2277,
#  'obviously': 1843,
#  'excite': 845,
#  'local': 1523,
#  'network': 1800,
#  'heaven': 1203,
#  'ready': 2138,
#  'night': 1808,
#  'fun': 1057,
#  'notice': 1827,
#  'arnold': 131,
#  'simply': 2416,
#  'famous': 897,
#  'book': 283,
#  'maybe': 1632,
#  'hide': 1216,
#  'soon': 2471,
#  'write': 2976,
#  'entire': 808,
#  'story': 2543,
#  'standard': 2513,
#  'hero': 1212,
#  'solve': 2466,
#  'problem': 2057,
#  'scar': 2309,
#  'away': 173,
#  'stun': 2571,
#  'say': 2304,
#  'screen': 2329,
#  'literally': 1516,
#  'tie': 2719,
#  'title': 2734,
#  'waste': 2896,
#  'note': 1826,
#  'ashamed': 138,
#  'want': 2883,
#  'embarrass': 774,
#  'big fan': 246,
#  'make film': 1583,
#  'good film': 1109,
#  'film know': 957,
#  'story make': 2547,
#  'film say': 970,
#  'say film': 2305,
#  'film bad': 944,
#  'lot people': 1545,
#  'terrible': 2671,
#  'scene': 2314,
#  'emotion': 778,
#  'draw': 733,
#  'predictable': 2023,
#  'line': 1508,
#  'obvious': 1842,
#  'typical': 2796,
#  'hollywood': 1237,
#  'william': 2934,
#  'sad': 2285,
#  'role': 2260,
#  'early': 753,
#  'look': 1531,
#  'like': 1498,
#  'script': 2334,
#  'attractive': 160,
#  'dog': 716,
#  'road': 2253,
#  'sexy': 2374,
#  'erotic': 820,
#  'connection': 519,
#  'age': 62,
#  'eastwood': 759,
#  'direct': 690,
#  'place': 1965,
#  'pre': 2021,
#  'cool': 545,
#  'swing': 2629,
#  'old': 1859,
#  'desperately': 665,
#  'free': 1042,
#  'spirit': 2497,
#  'saw': 2301,
#  'laurel': 1464,
#  'car': 363,
#  'youth': 2996,
#  'culture': 596,
#  'desperate': 664,
#  'story line': 2546,
#  'look like': 1535,
#  'new': 1801,
#  'expect': 855,
#  'boat': 275,
#  'drink': 737,
#  'contain': 529,
#  'excellent': 841,
#  'scientist': 2324,
#  'person': 1939,
#  'material': 1624,
#  'cover': 563,
#  'science': 2322,
#  'fell': 926,
#  'asleep': 142,
#  'time': 2723,
#  'stop': 2540,
#  'documentary': 715,
#  'late': 1456,
#  'blockbuster': 267,
#  'fall': 891,
#  'far': 902,
#  'provide': 2083,
#  'worth': 2967,
#  'avoid': 170,
#  'cost': 554,
#  'watch movie': 2901,
#  'second time': 2343,
#  'originally': 1876,
#  'suppose': 2608,
#  'dig': 686,
#  'bush': 339,
#  'awful': 175,
#  'minor': 1678,
#  'spoiler': 2501,
#  'semi': 2352,
#  'cut': 601,
#  'half': 1170,
#  'sequence': 2359,
#  'boyfriend': 295,
#  'storyline': 2550,
#  'contrive': 537,
#  'dialog': 676,
#  'wood': 2954,
#  'come': 479,
#  'favor': 914,
#  'decent': 633,
#  'grade': 1130,
#  'disaster': 699,
#  'mess': 1653,
#  'crap': 567,
#  'believable': 226,
#  'movie come': 1722,
#  'doubt': 724,
#  'funniest': 1061,
#  'stooge': 2539,
#  'dozen': 727,
#  'laugh': 1459,
#  'hilarious': 1222,
#  'perfect': 1932,
#  'example': 840,
#  'musical': 1769,
#  'comedy': 483,
#  'remember': 2200,
#  'time make': 2725,
#  'make laugh': 1587,
#  'people like': 1927,
#  'best': 235,
#  'lesbian': 1484,
#  'bring': 312,
#  'true': 2780,
#  'set': 2366,
#  'amaze': 86,
#  'desire': 663,
#  'woman': 2950,
#  'expectation': 856,
#  'actress': 37,
#  'connect': 518,
#  'pain': 1892,
#  'important': 1299,
#  'twice': 2791,
#  'bbc': 210,
#  'need': 1795,
#  'portray': 2002,
#  'real': 2139,
#  'hurt': 1277,
#  'live': 1520,
#  'dvd': 750,
#  'thrill': 2712,
#  'purchase': 2093,
#  'film think': 975,
#  'feature': 920,
#  'young': 2991,
#  'keaton': 1416,
#  'fresh': 1048,
#  'split': 2499,
#  'family': 896,
#  'debut': 631,
#  'funny': 1062,
#  'overall': 1882,
#  'boy': 294,
#  'pure': 2094,
#  'fashion': 906,
#  'slapstick': 2437,
#  'brief': 307,
#  'era': 818,
#  'reel': 2175,
#  'filmmaker': 984,
#  'imagine': 1293,
#  'segment': 2349,
#  'matter': 1627,
#  'course': 560,
#  'general': 1078,
#  'store': 2541,
#  'excuse': 847,
#  'possibility': 2008,
#  'fast': 907,
#  'physical': 1952,
#  'humor': 1272,
#  'pound': 2014,
#  'demonstrate': 650,
#  'subtlety': 2583,
#  'skill': 2432,
#  'grace': 1129,
#  'routine': 2271,
#  'raise': 2118,
#  'different': 684,
#  'level': 1490,
#  'gag': 1065,
#  'large': 1453,
#  'knife': 1434,
#  'spin': 2496,
#  'proper': 2076,
#  'position': 2005,
#  'stick': 2534,
#  'board': 274,
#  'nice': 1805,
#  'scale': 2308,
#  'confuse': 516,
#  'meat': 1636,
#  'buy': 344,
#  'perform': 1935,
#  'foot': 1013,
#  'floor': 1003,
#  'follow': 1010,
#  'apart': 113,
#  'odd': 1849,
#  'smile': 2452,
#  'attitude': 157,
#  'body': 278,
#  'language': 1452,
#  'immediately': 1295,
#  'eventually': 832,
#  'hat': 1193,
#  'destroy': 667,
#  'situation': 2430,
#  'base': 200,
#  'rival': 2251,
#  'john': 1394,
#  'dress': 736,
#  'drag': 729,
#  'girlfriend': 1094,
#  'school': 2320,
#  'generally': 1079,
#  'surreal': 2616,
#  'sight': 2405,
#  'fellow': 927,
#  'wear': 2915,
#  'stand': 2512,
#  'occasional': 1845,
#  'help': 1210,
#  'ending': 788,
#  'little': 1517,
#  'historical': 1227,
#  'film quite': 967,
#  'second half': 2342,
#  'brilliant': 310,
#  'father': 912,
#  'son': 2469,
#  'team': 2652,
#  'pilot': 1961,
#  'england': 794,
#  'battle': 209,
#  'britain': 313,
#  'beautiful': 215,
#  'incredibly': 1309,
#  'realistic': 2143,
#  'probably': 2055,
#  'number': 1834,
#  'theme': 2688,
#  'war': 2888,
#  'romance': 2263,
#  'loss': 1542,
#  'trial': 2773,
#  'learn': 1476,
#  'foreign': 1018,
#  'easy': 760,
#  'anna': 104,
#  'motif': 1707,
#  'device': 673,
#  'point': 1986,
#  'nicely': 1806,
#  'reflect': 2178,
#  'black': 257,
#  'record': 2171,
#  'music': 1768,
#  'plus': 1984,
#  'traditional': 2756,
#  'english': 795,
#  'beer': 219,
#  'glass': 1096,
#  'unlike': 2824,
#  'post': 2011,
#  'straight': 2552,
#  'china': 426,
#  'country': 557,
#  'surround': 2617,
#  'south': 2480,
#  'seven': 2369,
#  'sister': 2426,
#  'southern': 2481,
#  'score': 2325,
#  'tradition': 2755,
#  'ron': 2266,
#  'original': 1873,
#  'classic': 452,
#  'cameo': 350,
#  'apparently': 118,
#  'musician': 1770,
#  'kevin': 1419,
#  'piano': 1954,
#  'song': 2470,
#  'dark': 616,
#  'blue': 273,
#  'sky': 2435,
#  'float': 1002,
#  'susan': 2620,
#  'charles': 409,
#  'dance': 609,
#  'fine': 989,
#  'wing': 2940,
#  'highly': 1220,
#  'recommend': 2168,
#  'hire': 1226,
#  'special': 2487,
#  'stuff': 2569,
#  'create': 571,
#  'fight': 937,
#  'combine': 478,
#  'subtitle': 2581,
#  'speak': 2486,
#  'german': 1088,
#  'french': 1046,
#  'probably best': 2056,
#  'film great': 956,
#  'highly recommend': 1221,
#  'worth watch': 2968,
#  'enjoyable': 801,
#  'random': 2119,
#  'piece': 1958,
#  'cinema': 440,
#  'emerge': 775,
#  'recently': 2166,
#  'view': 2858,
#  'form': 1024,
#  'lose': 1540,
#  'modern': 1692,
#  'child': 423,
#  'mysterious': 1771,
#  'event': 831,
#  'field': 936,
#  'reward': 2239,
#  'merely': 1651,
#  'wave': 2905,
#  'train': 2761,
#  'seemingly': 2348,
#  'simple': 2415,
#  'vhs': 2850,
#  'minute': 1679,
#  'realize': 2145,
#  'common': 492,
#  'adventure': 53,
#  'track': 2753,
#  'bend': 232,
#  'cinematic': 441,
#  'technique': 2656,
#  'regular': 2184,
#  'viewer': 2859,
#  'question': 2103,
#  'treasure': 2768,
#  'alike': 78,
#  'moment': 1694,
#  'transform': 2763,
#  'happen': 1181,
#  'bobby': 277,
#  'peter': 1946,
#  'assure': 148,
#  'darkness': 617,
#  'laughter': 1462,
#  'prove': 2082,
#  'small': 2449,
#  'village': 2860,
#  'final': 985,
#  'star': 2515,
#  'advance': 51,
#  'lead': 1470,
#  'realism': 2142,
#  'today': 2735,
#  'imagination': 1291,
#  'pack': 1890,
#  'witness': 2947,
#  'favorite': 915,
#  'handle': 1177,
#  'birthday': 252,
#  'guest': 1161,
#  'gift': 1092,
#  'refresh': 2179,
#  'mind': 1675,
#  'capture': 362,
#  'attention': 156,
#  'ask': 141,
#  'state': 2520,
#  'reaction': 2133,
#  'adult': 50,
#  'tiny': 2732,
#  'genuine': 1085,
#  'creative': 573,
#  'couple': 558,
#  'direction': 691,
#  'job': 1392,
#  'guess': 1160,
#  'occur': 1847,
#  'suddenly': 2590,
#  'opportunity': 1868,
#  'wide': 2930,
#  'shot': 2397,
#  'breath': 302,
#  'bit': 253,
#  'close': 461,
#  'background': 179,
#  'chuckle': 438,
#  'distract': 711,
#  'picture': 1956,
#  'oddly': 1850,
#  'british': 314,
#  'produce': 2060,
#  'actually': 39,
#  'power': 2016,
#  'excitement': 846,
#  'community': 493,
#  'town': 2751,
#  'afraid': 58,
#  'audience': 161,
#  'remain': 2197,
#  'player': 1975,
#  'opening': 1863,
#  'explode': 862,
#  'friendly': 1051,
#  'ability': 1,
#  'involve': 1357,
#  'outstanding': 1881,
#  'strong': 2562,
#  'disney': 708,
#  'release': 2192,
#  'friendship': 1052,
#  'stranger': 2555,
#  'kid': 1423,
#  'visual': 2869,
#  'courage': 559,
#  'cgi': 390,
#  'guy': 1167,
#  'minute film': 1680,
#  'film year': 983,
#  'enjoy film': 798,
#  'love film': 1551,
#  'great job': 1142,
#  'feel like': 925,
#  'scene film': 2315,
#  'film like': 958,
#  'opening scene': 1865,
#  'bad guy': 185,
#  'die': 681,
#  'hard': 1186,
#  'suffer': 2591,
#  'season': 2339,
#  'trek': 2772,
#  'deep': 636,
#  'space': 2483,
#  'answer': 108,
#  'fantastic': 900,
#  'perspective': 1944,
#  'visuals': 2871,
#  'pop': 1998,
#  'shock': 2391,
#  'sign': 2406,
#  'die hard': 682,
#  'star trek': 2516,
#  'wonder': 2951,
#  'plain': 1967,
#  'ridiculous': 2245,
#  'read': 2134,
#  'cheesy': 419,
#  'circle': 443,
#  'attraction': 159,
#  'student': 2566,
#  'principal': 2048,
#  'civil': 447,
#  'mary': 1615,
#  'annoying': 107,
#  'bob': 276,
#  'teacher': 2651,
#  'lift': 1495,
#  'virgin': 2865,
#  'sit': 2427,
#  'enter': 805,
#  'service': 2365,
#  'silly': 2410,
#  'stretch': 2558,
#  'walk': 2877,
#  'horribly': 1252,
#  'key': 1420,
#  'business': 340,
#  'compel': 497,
#  'hair': 1169,
#  'woody': 2956,
#  'animal': 99,
#  'brother': 319,
#  'madness': 1568,
#  'make movie': 1590,
#  'civil war': 448,
#  'actually make': 40,
#  'change': 396,
#  'doctor': 714,
#  'decide': 634,
#  'male': 1598,
#  'proceed': 2058,
#  'history': 1228,
#  'college': 471,
#  'break': 300,
#  'happy': 1184,
#  'handsome': 1178,
#  'roger': 2259,
#  'yes': 2988,
#  'novel': 1829,
#  'gore': 1123,
#  'naturally': 1784,
#  'anti': 110,
#  'bunch': 333,
#  'professional': 2065,
#  'andy': 94,
#  'jim': 1389,
#  'west': 2925,
#  'surprise': 2614,
#  'absolute': 3,
#  'rat': 2127,
#  'lower': 1558,
#  'truly': 2782,
#  'attempt': 154,
#  'jump': 1408,
#  'bore': 286,
#  'horrible': 1251,
#  'scenery': 2318,
#  'extreme': 874,
#  'hardly': 1188,
#  'sick': 2403,
#  'crack': 565,
#  'joke': 1398,
#  'disbelief': 700,
#  'people say': 1930,
#  'thing make': 2695,
#  'year old': 2986,
#  'thing say': 2697,
#  'okay': 1858,
#  'robot': 2257,
#  'offer': 1853,
#  'bet': 241,
#  'turn': 2790,
#  'complain': 500,
#  'fade': 882,
#  'killer': 1427,
#  'dirty': 694,
#  'harry': 1191,
#  'touch': 2747,
#  'date': 618,
#  'sci': 2321,
#  'romantic': 2264,
#  'issue': 1364,
#  'overlook': 1884,
#  'movie people': 1740,
#  'romantic comedy': 2265,
#  'movie want': 1756,
#  'want watch': 2887,
#  'godfather': 1101,
#  'executive': 850,
#  'complex': 504,
#  'tale': 2636,
#  'extend': 870,
#  'violence': 2863,
#  'nudity': 1833,
#  'gratuitous': 1134,
#  'contrast': 535,
#  'tony': 2742,
#  'gangster': 1069,
#  'reality': 2144,
#  'bear': 212,
#  'frankly': 1038,
#  'associate': 146,
#  'sun': 2598,
#  'beat': 214,
#  'death': 630,
#  'pan': 1899,
#  'fit': 993,
#  'eat': 761,
#  'jar': 1376,
#  'advice': 54,
#  'marriage': 1609,
#  'finish': 991,
#  'sunday': 2599,
#  'afternoon': 61,
#  'football': 1015,
#  'wife': 2932,
#  'prefer': 2024,
#  'trust': 2783,
#  'point view': 1989,
#  'worst': 2964,
#  'suck': 2588,
#  'main': 1573,
#  'friend': 1050,
#  'pick': 1955,
#  'producer': 2061,
#  'super': 2600,
#  'kidnap': 1424,
#  'steal': 2526,
#  'identity': 1284,
#  'wow': 2972,
#  'especially': 823,
#  'emily': 776,
#  'sleep': 2442,
#  'dumb': 747,
#  'worst movie': 2966,
#  'movie story': 1751,
#  'say movie': 2307,
#  'main character': 1574,
#  'movie make': 1737,
#  'waste time': 2898,
#  'think movie': 2702,
#  'movie like': 1731,
#  'like make': 1501,
#  'lady': 1446,
#  'weird': 2921,
#  'director': 693,
#  'welles': 2923,
#  'moon': 1701,
#  'noir': 1811,
#  'period': 1938,
#  'type': 2794,
#  'popular': 1999,
#  'concern': 510,
#  'lucky': 1560,
#  'marry': 1610,
#  'husband': 1278,
#  'sea': 2335,
#  'law': 1465,
#  'partner': 1910,
#  'trouble': 2778,
#  'speech': 2491,
#  'suicide': 2593,
#  'topic': 2743,
#  'suggest': 2592,
#  'mental': 1647,
#  'murder': 1765,
#  'ensue': 804,
#  'pace': 1888,
#  'consist': 523,
#  'drive': 738,
#  'possess': 2007,
#  'result': 2229,
#  'watchable': 2903,
#  'career': 366,
#  'vehicle': 2847,
#  'self': 2350,
#  'destruction': 668,
#  'fetch': 933,
#  'beauty': 217,
#  'appeal': 119,
#  'personality': 1942,
#  'quality': 2100,
#  'strangely': 2554,
#  'thirty': 2705,
#  'sean': 2337,
#  'connery': 520,
#  'robert': 2255,
#  'able': 2,
#  'photograph': 1950,
#  'bizarre': 256,
#  'edit': 764,
#  'disturb': 712,
#  'method': 1656,
#  'talented': 2638,
#  'intelligent': 1338,
#  'tend': 2667,
#  'statement': 2521,
#  'agree': 65,
#  'brilliantly': 311,
#  'forth': 1027,
#  'sum': 2595,
#  'reach': 2131,
#  'studio': 2567,
#  'exactly': 838,
#  'nose': 1823,
#  'thumb': 2717,
#  'day': 624,
#  'suspect': 2621,
#  'portrait': 2001,
#  'lawyer': 1466,
#  'express': 868,
#  'opinion': 1867,
#  'present': 2030,
#  'certainly': 389,
#  'citizen': 445,
#  'kane': 1413,
#  'cause': 382,
#  'fully': 1056,
#  'dare': 615,
#  'personal': 1941,
#  'failure': 884,
#  'deliver': 646,
#  'promise': 2071,
#  'mere': 1650,
#  'fact': 880,
#  'presence': 2029,
#  'control': 538,
#  'naive': 1774,
#  'lack': 1445,
#  'knowledge': 1440,
#  'inside': 1327,
#  'aspect': 143,
#  'film noir': 965,
#  'end film': 785,
#  'year late': 2985,
#  'low': 1556,
#  'amazingly': 87,
#  'comment': 488,
#  'similar': 2412,
#  'scheme': 2319,
#  'reference': 2177,
#  'average': 169,
#  'curse': 600,
#  'exaggerate': 839,
#  'unfortunately': 2812,
#  'hour': 1265,
#  'entertainment': 807,
#  'beautifully': 216,
#  'remind': 2201,
#  'hope': 1249,
#  'focus': 1008,
#  'try make': 2787,
#  'hour half': 1266,
#  'movie start': 1750,
#  'thoroughly': 2707,
#  'impress': 1301,
#  'territory': 2675,
#  'sell': 2351,
#  'hit': 1229,
#  'pitch': 1962,
#  'city': 446,
#  'mainly': 1575,
#  'satire': 2296,
#  'seriously': 2363,
#  'non': 1815,
#  'rock': 2258,
#  'solid': 2465,
#  'impressive': 1303,
#  'consider': 522,
#  'budget': 325,
#  'deadly': 626,
#  'current': 599,
#  'idea': 1281,
#  'lover': 1555,
#  'baby': 177,
#  'dialogue': 677,
#  'central': 386,
#  'european': 829,
#  'accent': 10,
#  'reveal': 2232,
#  'unite': 2818,
#  'strike': 2559,
#  'thriller': 2713,
#  'match': 1622,
#  'african': 60,
#  'police': 1991,
#  'chief': 422,
#  'sound': 2475,
#  'officer': 1855,
#  'george': 1087,
#  'scott': 2326,
#  'concentrate': 508,
#  'strange': 2553,
#  'site': 2429,
#  'nation': 1780,
#  'curious': 598,
#  'agent': 63,
#  'intelligence': 1337,
#  'scratch': 2327,
#  'head': 1197,
#  'heck': 1206,
#  'unite state': 2819,
#  'sound like': 2477,
#  'thing happen': 2693,
#  'accomplish': 16,
#  'travel': 2767,
#  'satisfy': 2297,
#  'unless': 2823,
#  'air': 69,
#  'forget': 1021,
#  'improve': 1304,
#  'fest': 931,
#  'supernatural': 2604,
#  'element': 772,
#  'kill': 1425,
#  'victim': 2851,
#  'normal': 1819,
#  'bullet': 331,
#  'mouth': 1713,
#  'cheap': 413,
#  'strongly': 2563,
#  'horror': 1255,
#  'movie little': 1732,
#  'little bit': 1518,
#  'like movie': 1502,
#  'horror movie': 1259,
#  'movie good': 1728,
#  'preview': 2040,
#  'figure': 940,
#  'case': 372,
#  'twist': 2793,
#  'clip': 460,
#  'appear': 120,
#  'funnier': 1060,
#  'particularly': 1909,
#  'unfunny': 2813,
#  'comedic': 482,
#  'tone': 2740,
#  'pretty': 2036,
#  'pass': 1912,
#  'allow': 81,
#  'disappoint': 697,
#  'glad': 1095,
#  'theater': 2685,
#  'really want': 2159,
#  'movie saw': 1747,
#  'really funny': 2150,
#  'pretty good': 2038,
#  'list': 1514,
#  'teenage': 2661,
#  'word': 2957,
#  'letter': 1489,
#  'nick': 1807,
#  'talk': 2639,
#  'basically': 204,
#  'animate': 100,
#  'wealthy': 2913,
#  'cat': 377,
#  'gordon': 1122,
#  'join': 1397,
#  'human': 1270,
#  'party': 1911,
#  'root': 2268,
#  'save': 2300,
#  'planet': 1970,
#  'evil': 836,
#  'bone': 282,
#  'memorable': 1643,
#  'voice': 2872,
#  'include': 1306,
#  'wayne': 2910,
#  ...}

# %%
x=pd.DataFrame({'keys':list(tfv.vocabulary_.keys()),'values':list(tfv.vocabulary_.values())})
x=x.sort_values(['values'],ascending=[0])
x.tail()
# Out:
#             keys  values
# 1079  absolutely       4
# 677     absolute       3
# 816         able       2
# 582      ability       1
# 1022     abandon       0

# %%
x=pd.DataFrame({'keys':list(tfv.vocabulary_.keys()),'values':list(tfv.idf_)})
x=x.sort_values(['values'],ascending=[0])
x.tail(50)
# Out:
#                   keys    values
# 1986             japan  3.050136
# 2518              gory  3.030138
# 2665        thing like  3.015173
# 1529            center  3.012775
# 2515         sacrifice  3.011280
# 244               fall  3.006211
# 2976               usa  3.002204
# 1936          gruesome  2.986919
# 39              cringe  2.986044
# 1477              bath  2.980956
# 2833              shoe  2.956607
# 374           language  2.944371
# 2139            resort  2.912457
# 1859             value  2.873163
# 693         thing make  2.866029
# 1543             order  2.864996
# 923             nation  2.847081
# 1599            convey  2.823270
# 1517       imaginative  2.666452
# 2785           lovable  2.648823
# 235              cover  2.641052
# 2983         instantly  2.621227
# 2883             plant  2.600498
# 34              monkey  2.591323
# 2958           act bad  2.582427
# 1979             karen  2.566877
# 1493        love story  2.562670
# 784            husband  2.536022
# 1973              cell  2.482209
# 1550              hold  2.481593
# 2691         obsession  2.418342
# 1925               sam  2.394185
# 479   highly recommend  2.384157
# 2906          catholic  2.367610
# 1137           develop  2.359400
# 180         story make  2.337296
# 2314       fight scene  2.330615
# 23               earth  2.303739
# 1437        importance  2.301091
# 2304          good bad  2.300210
# 1531              ugly  2.293990
# 2146       unrealistic  2.200798
# 2543           imagery  2.162915
# 2698           rubbish  2.113117
# 399        second half  2.108622
# 2899             julie  2.003940
# 1105        technology  1.963769
# 2723           massive  1.890789
# 1498              dude  1.707753
# 1580              cash  1.656372

# %%
len(tfv.vocabulary_),len(tfv.idf_)
# Out:
# (3000, 3000)

# %%
tfv.vocabulary_.keys()
# Out:
# dict_keys(['quite', 'enjoy', 'reason', 'insight', 'world', 'rarely', 'treat', 'tell', 'struggle', 'second', 'performance', 'actor', 'think', 'honest', 'convince', 'portrayal', 'people', 'hear', 'outside', 'native', 'entertain', 'irish', 'cast', 'earth', 'slightly', 'open', 'eye', 'enjoy movie', 'man', 'land', 'meet', 'girl', 'life', 'sort', 'monkey', 'hook', 'teach', 'fly', 'leave', 'cringe', 'induce', 'aside', 'short', 'make', 'sense', 'plot', 'sure', 'long', 'shoot', 'work', 'despite', 'good', 'use', 'slow', 'motion', 'series', 'video', 'believe', 'short film', 'film make', 'make sense', 'really', 'begin', 'start', 'chance', 'deserve', 'home', 'watch', 'television', 'know', 'talent', 'sing', 'competition', 'american', 'year', 'miss', 'potential', 'feel', 'bad', 'singer', 'grow', 'wish', 'cancel', 'complaint', 'care', 'judge', 'joy', 'shakespeare', 'single', 'right', 'wrong', 'thing', 'kind', 'action', 'god', 'sake', 'play', 'instead', 'dead', 'end', 'act', 'production', 'try', 'explain', 'sexual', 'disgust', 'total', 'mother', 'uncle', 'bed', 'utter', 'mean', 'relationship', 'impossible', 'slight', 'hint', 'sex', 'throw', 'character', 'lot', 'way', 'understand', 'manage', 'mark', 'great', 'completely', 'let', 'rest', 'face', 'prince', 'good actor', 'make great', 'great film', 'rest cast', 'big', 'fan', 'stephen', 'king', 'love', 'run', 'obviously', 'excite', 'local', 'network', 'heaven', 'ready', 'night', 'fun', 'notice', 'arnold', 'simply', 'famous', 'book', 'maybe', 'hide', 'soon', 'write', 'entire', 'story', 'standard', 'hero', 'solve', 'problem', 'scar', 'away', 'stun', 'say', 'screen', 'literally', 'tie', 'title', 'waste', 'note', 'ashamed', 'want', 'embarrass', 'big fan', 'make film', 'good film', 'film know', 'story make', 'film say', 'say film', 'film bad', 'lot people', 'terrible', 'scene', 'emotion', 'draw', 'predictable', 'line', 'obvious', 'typical', 'hollywood', 'william', 'sad', 'role', 'early', 'look', 'like', 'script', 'attractive', 'dog', 'road', 'sexy', 'erotic', 'connection', 'age', 'eastwood', 'direct', 'place', 'pre', 'cool', 'swing', 'old', 'desperately', 'free', 'spirit', 'saw', 'laurel', 'car', 'youth', 'culture', 'desperate', 'story line', 'look like', 'new', 'expect', 'boat', 'drink', 'contain', 'excellent', 'scientist', 'person', 'material', 'cover', 'science', 'fell', 'asleep', 'time', 'stop', 'documentary', 'late', 'blockbuster', 'fall', 'far', 'provide', 'worth', 'avoid', 'cost', 'watch movie', 'second time', 'originally', 'suppose', 'dig', 'bush', 'awful', 'minor', 'spoiler', 'semi', 'cut', 'half', 'sequence', 'boyfriend', 'storyline', 'contrive', 'dialog', 'wood', 'come', 'favor', 'decent', 'grade', 'disaster', 'mess', 'crap', 'believable', 'movie come', 'doubt', 'funniest', 'stooge', 'dozen', 'laugh', 'hilarious', 'perfect', 'example', 'musical', 'comedy', 'remember', 'time make', 'make laugh', 'people like', 'best', 'lesbian', 'bring', 'true', 'set', 'amaze', 'desire', 'woman', 'expectation', 'actress', 'connect', 'pain', 'important', 'twice', 'bbc', 'need', 'portray', 'real', 'hurt', 'live', 'dvd', 'thrill', 'purchase', 'film think', 'feature', 'young', 'keaton', 'fresh', 'split', 'family', 'debut', 'funny', 'overall', 'boy', 'pure', 'fashion', 'slapstick', 'brief', 'era', 'reel', 'filmmaker', 'imagine', 'segment', 'matter', 'course', 'general', 'store', 'excuse', 'possibility', 'fast', 'physical', 'humor', 'pound', 'demonstrate', 'subtlety', 'skill', 'grace', 'routine', 'raise', 'different', 'level', 'gag', 'large', 'knife', 'spin', 'proper', 'position', 'stick', 'board', 'nice', 'scale', 'confuse', 'meat', 'buy', 'perform', 'foot', 'floor', 'follow', 'apart', 'odd', 'smile', 'attitude', 'body', 'language', 'immediately', 'eventually', 'hat', 'destroy', 'situation', 'base', 'rival', 'john', 'dress', 'drag', 'girlfriend', 'school', 'generally', 'surreal', 'sight', 'fellow', 'wear', 'stand', 'occasional', 'help', 'ending', 'little', 'historical', 'film quite', 'second half', 'brilliant', 'fa ...

# %%
tfv.idf_
# Out:
# array([5.61726277, 4.85850224, 4.05168791, ..., 5.44307134, 5.20239531,
#        6.22137633])

# %%
pd.DataFrame(data=train_data_features.toarray())

# %%
train_data_features
# Out:
# <25000x3000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 
#  'start pretty well accident decision return la everything fall place quickly decent plot twist towards end many scene make sense randy play brian austin green come home angry ready confront people take time put club park car front house middle nowhere want spoil anyone decide see last minute ridiculous even act bad early turn bad towards end bother unless want see bad',
#  'film harmless escapist fun something recent tomb raider film lack wait get dvd people give low score still go see titanic without guilty conscience know anything karen kopins underwear get rate extra point two',
#  'even without speak word billy connely wonderful zombie carrie ann moss mom even well zombie girlfriend father thied eat never try eat timmy think dawn dead good kinda like airplane meet meat night live dead sponsor zomcom forget head coffinand fido aloha shirt way cool yes social comment much even begin comment sufice say really work',
#  'saw movie tribeca film festival say think amaze combination humor sincerity really make movie worthwhile movie seventeen year old boy whose mother father religious seventeen year old ben decide work retire actress teach girl drive life comical touch honestly say one favorite movie recommend movie anyone everyone catch one show film festival suppose come theater late year please go see great film',
#  'kim basinger mickey rourke star controversial story wall street exec art gallery employee hook begin experimental sexual relationship act rourke basinger ok flim allow character truly form allegedly lot film leave cut room floor delve deep character effect relationship basinger character consider suicide would make character involve viewer glossy well produce mtv style edit piece soft core voyeurism',
#  'thoroughly enjoy flick firm belief matt stone trey parker comic genius time uncanny ability add level absurdity pop culture make rediculous realistic way make sense mainly make south park soooo funny get past fact probably vulgar indiscreet cartoon ever see every episode message convey apparent baseketball although direct david zucker utterly rediculous sincere message corporate america disgrace major league sport also fan sport find movie hilarious time true bizarre way people hate love opening prologue brilliant tear laughter form everytime see football player begin riverdance may like movie everyone cup tea like south park look past absurdity really genuine message convey literal comic genius give movie star',
#  ...]

# %%
tfv.vocabulary_.keys()
# Out:
# dict_keys(['quite', 'enjoy', 'reason', 'insight', 'world', 'rarely', 'treat', 'tell', 'struggle', 'second', 'performance', 'actor', 'think', 'honest', 'convince', 'portrayal', 'people', 'hear', 'outside', 'native', 'entertain', 'irish', 'cast', 'earth', 'slightly', 'open', 'eye', 'enjoy movie', 'man', 'land', 'meet', 'girl', 'life', 'sort', 'monkey', 'hook', 'teach', 'fly', 'leave', 'cringe', 'induce', 'aside', 'short', 'make', 'sense', 'plot', 'sure', 'long', 'shoot', 'work', 'despite', 'good', 'use', 'slow', 'motion', 'series', 'video', 'believe', 'short film', 'film make', 'make sense', 'really', 'begin', 'start', 'chance', 'deserve', 'home', 'watch', 'television', 'know', 'talent', 'sing', 'competition', 'american', 'year', 'miss', 'potential', 'feel', 'bad', 'singer', 'grow', 'wish', 'cancel', 'complaint', 'care', 'judge', 'joy', 'shakespeare', 'single', 'right', 'wrong', 'thing', 'kind', 'action', 'god', 'sake', 'play', 'instead', 'dead', 'end', 'act', 'production', 'try', 'explain', 'sexual', 'disgust', 'total', 'mother', 'uncle', 'bed', 'utter', 'mean', 'relationship', 'impossible', 'slight', 'hint', 'sex', 'throw', 'character', 'lot', 'way', 'understand', 'manage', 'mark', 'great', 'completely', 'let', 'rest', 'face', 'prince', 'good actor', 'make great', 'great film', 'rest cast', 'big', 'fan', 'stephen', 'king', 'love', 'run', 'obviously', 'excite', 'local', 'network', 'heaven', 'ready', 'night', 'fun', 'notice', 'arnold', 'simply', 'famous', 'book', 'maybe', 'hide', 'soon', 'write', 'entire', 'story', 'standard', 'hero', 'solve', 'problem', 'scar', 'away', 'stun', 'say', 'screen', 'literally', 'tie', 'title', 'waste', 'note', 'ashamed', 'want', 'embarrass', 'big fan', 'make film', 'good film', 'film know', 'story make', 'film say', 'say film', 'film bad', 'lot people', 'terrible', 'scene', 'emotion', 'draw', 'predictable', 'line', 'obvious', 'typical', 'hollywood', 'william', 'sad', 'role', 'early', 'look', 'like', 'script', 'attractive', 'dog', 'road', 'sexy', 'erotic', 'connection', 'age', 'eastwood', 'direct', 'place', 'pre', 'cool', 'swing', 'old', 'desperately', 'free', 'spirit', 'saw', 'laurel', 'car', 'youth', 'culture', 'desperate', 'story line', 'look like', 'new', 'expect', 'boat', 'drink', 'contain', 'excellent', 'scientist', 'person', 'material', 'cover', 'science', 'fell', 'asleep', 'time', 'stop', 'documentary', 'late', 'blockbuster', 'fall', 'far', 'provide', 'worth', 'avoid', 'cost', 'watch movie', 'second time', 'originally', 'suppose', 'dig', 'bush', 'awful', 'minor', 'spoiler', 'semi', 'cut', 'half', 'sequence', 'boyfriend', 'storyline', 'contrive', 'dialog', 'wood', 'come', 'favor', 'decent', 'grade', 'disaster', 'mess', 'crap', 'believable', 'movie come', 'doubt', 'funniest', 'stooge', 'dozen', 'laugh', 'hilarious', 'perfect', 'example', 'musical', 'comedy', 'remember', 'time make', 'make laugh', 'people like', 'best', 'lesbian', 'bring', 'true', 'set', 'amaze', 'desire', 'woman', 'expectation', 'actress', 'connect', 'pain', 'important', 'twice', 'bbc', 'need', 'portray', 'real', 'hurt', 'live', 'dvd', 'thrill', 'purchase', 'film think', 'feature', 'young', 'keaton', 'fresh', 'split', 'family', 'debut', 'funny', 'overall', 'boy', 'pure', 'fashion', 'slapstick', 'brief', 'era', 'reel', 'filmmaker', 'imagine', 'segment', 'matter', 'course', 'general', 'store', 'excuse', 'possibility', 'fast', 'physical', 'humor', 'pound', 'demonstrate', 'subtlety', 'skill', 'grace', 'routine', 'raise', 'different', 'level', 'gag', 'large', 'knife', 'spin', 'proper', 'position', 'stick', 'board', 'nice', 'scale', 'confuse', 'meat', 'buy', 'perform', 'foot', 'floor', 'follow', 'apart', 'odd', 'smile', 'attitude', 'body', 'language', 'immediately', 'eventually', 'hat', 'destroy', 'situation', 'base', 'rival', 'john', 'dress', 'drag', 'girlfriend', 'school', 'generally', 'surreal', 'sight', 'fellow', 'wear', 'stand', 'occasional', 'help', 'ending', 'little', 'historical', 'film quite', 'second half', 'brilliant', 'fa ...

# %%
tfv.inverse_transform(train_data_features)[0]
# Out:
# array(['world', 'treat', 'think', 'tell', 'struggle', 'slightly',
#        'second', 'reason', 'rarely', 'quite', 'portrayal', 'performance',
#        'people', 'outside', 'open', 'native', 'irish', 'insight',
#        'honest', 'hear', 'eye', 'entertain', 'enjoy movie', 'enjoy',
#        'earth', 'convince', 'cast', 'actor'], dtype='<U21')
